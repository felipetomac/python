# %%
# !pip install scipy --user

# %%
import numpy as np

import imageio

# %%
img_array = imageio.imread('koala.jpg')

# %%
#RGB data
img_array.shape
# Out:
# (720, 902, 3)

# %%
type(img_array)
# Out:
# imageio.core.util.Array

# %%
img_array
# Out:
# Array([[[ 52,  62,  63],
#         [ 38,  50,  50],
#         [ 18,  32,  33],
#         ...,
#         [ 21,  38,   4],
#         [ 29,  47,   7],
#         [ 41,  60,  14]],
#
#        [[ 60,  70,  71],
#         [ 42,  52,  53],
#         [ 19,  30,  34],
#         ...,
#         [ 19,  36,   0],
#         [ 28,  46,   4],
#         [ 40,  60,  11]],
#
#        [[ 59,  67,  69],
#         [ 40,  50,  51],
#         [ 18,  29,  33],
#         ...,
#         [ 25,  43,   1],
#         [ 32,  51,   5],
#         [ 40,  60,   9]],
#
#        ...,
#
#        [[ 89,  63,  50],
#         [ 83,  59,  47],
#         [ 98,  74,  64],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 78,  52,  39],
#         [ 77,  50,  39],
#         [ 85,  61,  51],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 71,  45,  32],
#         [ 71,  44,  33],
#         [ 69,  45,  35],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img_array)
plt.show()

# %%
#all the rows starting from the row with index 300
#all the columns begining from 1 to index 250
#RGB values, retrieve everything (full color image)
sliced_image = img_array[300: , 250: , :]

# %%
sliced_image
# Out:
# Array([[[152, 169, 179],
#         [149, 167, 179],
#         [146, 165, 179],
#         ...,
#         [151, 182,  55],
#         [146, 177,  50],
#         [139, 170,  43]],
#
#        [[145, 162, 170],
#         [143, 161, 173],
#         [145, 164, 178],
#         ...,
#         [167, 198,  71],
#         [166, 197,  70],
#         [164, 195,  68]],
#
#        [[153, 170, 178],
#         [153, 171, 183],
#         [158, 177, 191],
#         ...,
#         [191, 221,  97],
#         [178, 208,  84],
#         [176, 206,  82]],
#
#        ...,
#
#        [[ 79,  99, 124],
#         [ 88, 108, 133],
#         [100, 120, 147],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 85, 103, 127],
#         [ 90, 110, 135],
#         [101, 121, 146],
#         ...,
#         [255, 253, 255],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[ 91, 109, 133],
#         [ 92, 110, 134],
#         [ 96, 114, 138],
# ...

# %%
plt.imshow(sliced_image)
plt.show()

# %%
x1, x2 = np.split(img_array, 2)

# %%
plt.imshow(x1)
plt.show()

# %%
plt.imshow(x2)
plt.show()

# %%
y1, y2 = np.split(img_array, 2, axis = 1)

# %%
plt.imshow(y1)
plt.show()

# %%
plt.imshow(y2)
plt.show()

# %%
plt.imshow(np.concatenate((x1,x2)))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(np.concatenate((y1,y2)))
plt.show()

# %%
plt.imshow(np.concatenate((y1,y2), axis = 1))
plt.show()
